# %% [markdown]
# <a href="https://colab.research.google.com/github/AJ-Horch/personal_finance_LLM/blob/main/analysing_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
articles_url = "https://raw.githubusercontent.com/AJ-Horch/personal_finance_LLM/refs/heads/main/clean_articles.csv"
articles = pd.read_csv(articles_url)

# %%
articles.sample(7)
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 982           3799        3799
# 956           3700        3700
# 271           1247        1247
# 245           1149        1149
# 1442          9521        9521
# 730           2855        2855
# 3                3           3
#
#                                                     url  \
# 982   https://www.cnbc.com/elections/?&qsearchterm=p...
# 956   https://www.cnbc.com/2020/07/30/small-business...
# 271   https://www.cnbc.com/video/2024/07/30/preventi...
# 245   https://www.cnbc.com/video/2022/04/28/sarat-se...
# 1442  https://www.cnbc.com/2023/10/21/social-securit...
# 730   https://www.cnbc.com/2024/04/18/heres-how-home...
# 3     https://www.cnbc.com/investing-in-india/?&qsea...
#
#                                         article_content  article
# 982   Got a confidential news tip? We want to hear f...      NaN
# 956   There may be a financial storm brewing at a ke...      NaN
# ...

# %% [markdown]
# Need to clean this DF up.
# - Remove the headers
# - remove article content
# - remove artilces that are only "Got a confidential tip..."
# - determine how many articles are actually suitable for analysis
